# %%
#1. ans -

Advantages of using functions -
  i) avoid repetition of codes
  ii) improve readability and reusability of the code
  iii) Reduce chance of errors.
    
    
2. ANS -

A code in a function runs when it's called.



3. ANS -

Define / def() is used to a function.



4. ANS -

Function call is using the function to do a particular task whereas,
A function is a procedure to achieve a particular result.



5. ANS -

One global scope is present per program execution.
Local scope is dependent on the number of local variables present in a function.



6. ANS - 

The variables in a local scope only exists while the function is being executed.When the execution of the function terminates (returns), the local variables are destroyed.



7. ANS -

A return is a value that the function returns to the calling function or the calling script when it completes it's task.
The value of expression, if present, is returned to the calling function. If expression is terminated, the return value of the function is undefined. The expression, if present, is evaluated and then converted to the type returned by the function.



8. ANS - 

If a function does not have a return statement then return value of the function will be undefined.



9.ANS -

We can make a function variable refer the global variable by using the global keyword.



10. ANS - 

None generally means null variable or null object and it's data type of it's own named NoneType.



11. ANS -

The import statement will import  areallyourpetsnamederic.



12. ANS - 

This function could be called with spam.bacon().




13. ANS - 

In the case of programme crashing we have to use try clause .



14. ANS - 

In the try clause, all statements are executed until an exception that is the error is encountered.
Except clause is used to catch and handle the exceptions that are encountered in the try clause.
