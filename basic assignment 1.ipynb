# %%
# 1. ANS :   

* , - , / , +  are expressions
-81.8 is an float
6 is an integer
'hello' is a string

 
2 . ANS - 

String is a sequence of characters, it can be letters,symbols etc.
Variable is something that stores data. Data can be string, int , float etc.


3. ANS - 

i) Text type - String  - String is a sequence of characters, it can be letters,symbols etc.
ii) Numeric types - int,float,complex 
iii) sequence type - list,tuple,range
iv) mapping types - dict : dictionary 
v) boolean type - bool


4. ANS -

Expressions can be made up of values,variables,operators etc.
Basically an expression is an instruction that combines values and operators and always evaluates down to a single value.


5. ANS - 

Expressions can be made up of values,variables,operators etc and expressions are mainly used to evaluate a value.
Statements generally represent an action or command ,  for example print statements,assignment statements.


6. ANS -

23.


7. ANS -

spamspamspam - values for both the terms


8. ANS - 

Why is eggs a valid variable name while 100 is invalid is because variables can not start with a number.


9. ANS - 

Functions used for 
integer  - int()
floating point - float()
String - str()

10. ANS - 

Reason for the error in this expression is because 99 is an integer and strings cannot be added/concatenated to other strings.
Correct way will be  - 
'I have eaten ' + str(99) + ' burritos'.
