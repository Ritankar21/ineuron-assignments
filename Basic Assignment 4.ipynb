# %%
#1 ANS -

[] it is an empty list which contains nothing.




2 ANS - 

spam[2] = 'hello'




3 ANS - 

Ans will be 'd' because the int will return the value 3 , so it will be spam[3] and it means the element present at the 4th position of the list.
And as already given in the question that at 4th position 'd' is there so the ans will be 'd'.



4 ANS - 

'd'



5. ANS - 

['a', 'b']




6 . ANS - 

1



7. ANS - 

[3.14,'cat',11,'cat',True,99]



8. ANS - 

[3.14,11,'cat',True]



9. ANS -

for list concatenation we use + ,
for list replication we use *




10. ANS -

While append() will add values only to the end of a list, insert() can add them anywhere in the list.




11. ANS - 

The del statement and the remove() list method are two ways to remove values from a list.





12. ANS - 

Both lists and strings can be passed to len(), have indexes and slices,can be used in for loops,can be concatenated or replicated, and can be used with the in and not in operators.




13. ANS  - 

Lists are mutable while tuples are immutable.Tuples are written using () whereas lists are written using [].




14. ANS - 

(42,)




15. ANS - 

The tuple() and list() functions, respectively.




16. ANS - 

They contain references to list values.



17. ANS - 

The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
